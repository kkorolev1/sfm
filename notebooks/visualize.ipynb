# %%
import os
import numpy as np
import cv2 as cv
import pickle
from matplotlib import pyplot as plt
import matplotlib.animation as animation

# %%
from estimate_trajectory import *
data_dir = "public_tests/00_test_slam_input"
config = SFMConfig()

frame_to_image_path = get_frame_to_image_path(data_dir)
frame_to_keypoints = get_frame_to_keypoints(
        frame_to_image_path, 
        data_dir=data_dir, 
        save_dir=config.keypoints_save_dir, 
        method=config.keypoints_method,
        n_keypoints=config.n_keypoints,
        overwrite_cache=config.keypoints_overwrite_cache
    )
frame_to_extrinsic_mat = get_frame_to_extrinsic_matrix(data_dir)
anchor_frames = list(frame_to_extrinsic_mat.keys())

# %%
frame_id = 0
img = cv.imread(frame_to_image_path[frame_id])
kp = frame_to_keypoints[frame_id].kp
plt.imshow(cv.drawKeypoints(img, kp, None, color=(0,255,0), flags=0))

# %%
frames_to_matches = match_anchor_keypoints(
    anchor_frames, frame_to_keypoints,
    method=config.matching_method,
    ratio_threshold=config.matching_ratio_threshold
)

# %%
# frame_id1 = 0
# frame_id2 = 1
# img1 = cv.imread(frame_to_image_path[frame_id1])
# img2 = cv.imread(frame_to_image_path[frame_id2])
# kp1 = frame_to_keypoints[frame_id1].kp
# kp2 = frame_to_keypoints[frame_id2].kp
# matches = frames_to_matches[(frame_id1, frame_id2)]
# matches_to_draw = 10
# matchesMask = np.zeros((len(matches)))
# matchesMask[np.random.choice(len(matches), matches_to_draw)] = 1
# draw_params = dict(matchColor = (0,255,0),
#                    singlePointColor = (255,0,0),
#                    matchesMask=matchesMask,
#                    flags = 0)
# plt.figure(figsize=(20,20))
# plt.imshow(cv.drawMatches(img1,kp1,img2,kp2,matches,None,**draw_params))

# %%
tracks = get_tracks(frames_to_matches, track_min_length=config.track_min_length)
print(f"num tracks {len(tracks)}")
# Out:
# num tracks 1495

# %%
# from matplotlib import pyplot as plt
# import matplotlib.animation as animation
# def plot_track(frame_to_image_paths, frame_to_keypoints, tracks, track_idx, out_dir="videos"):
#     os.makedirs(out_dir, exist_ok=True)
#     frames = []
#     fig = plt.figure()
#     track = tracks[track_idx]
#     print(f"Track {track_idx} of size {len(track)}")
#     for i in range(len(track)):
#         frame_id = track.get_frame(i)
#         pt = frame_to_keypoints[frame_id].kp[track[i]].pt
#         pt = tuple(map(int, pt))
#         img = cv.imread(frame_to_image_paths[frame_id])
#         img = cv.circle(img, pt, 5, color=(0, 255, 0), thickness=10)
#         frames.append([plt.imshow(img, animated=True)])
#     ani = animation.ArtistAnimation(fig, frames, interval=400, blit=True,
#                                 repeat_delay=1000)
#     ani.save(os.path.join(out_dir, f"track_{track_idx}.mp4"))

# %%
track_idx = 2 #list(sorted(enumerate(tracks), key=lambda x: -len(x[1])))[0][0]
plot_track(frame_to_image_path, frame_to_keypoints, tracks, track_idx)
# Out:
# Track 2 of size 15

# %%
plt.hist([len(track.items) for track in tracks], bins=25)
plt.yscale('log')
plt.title('Track length distribution')
plt.show()

# %%
plt.hist([track.frames[0] for track in tracks], bins=25);
plt.title('Track starting frame distribution');

# %%
plt.hist(np.array([frame for track in tracks for frame in track.frames]), bins=50);
plt.title('Frames distribution')
# Out:
# Text(0.5, 1.0, 'Frames distribution')

# %%
intrinsics_mat = get_intrinsics_matrix(data_dir)

good_tracks, tracks_points3d = triangulate_tracks(
    tracks, frame_to_keypoints, intrinsics_mat, frame_to_extrinsic_mat,
    reproj_error_threshold=config.reproj_error_threshold
)
print(f"Found {len(good_tracks)} good tracks!")
print(f"Mean good track length {np.mean([len(t) for t in good_tracks]):.3f}")
anchor_frame_to_keypoints = get_inliers_keypoints(good_tracks, tracks_points3d, frame_to_keypoints)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 intrinsics_mat = get_intrinsics_matrix(data_dir)
# ----> 3 good_tracks, tracks_points3d = triangulate_tracks(
#       4     tracks, frame_to_keypoints, intrinsics_mat, frame_to_extrinsic_mat,
#       5     reproj_error_threshold=config.reproj_error_threshold
#       6 )
#       7 print(f"Found {len(good_tracks)} good tracks!")
#       8 print(f"Mean good track length {np.mean([len(t) for t in good_tracks]):.3f}")
#
# File c:\Users\kirill-korolev\ami\sfm\estimate_trajectory.py:469, in triangulate_tracks(tracks, frame_to_keypoints, intrinsics_mat, frame_to_extrinsic_mat, reproj_error_threshold)
#     467 tracks_point3d = []
#     468 for track in tracks:
# --> 469     point3d = triangulate_track(
#     470         track, frame_to_keypoints, intrinsics_mat,
#     471         frame_to_extrinsic_mat, frame_to_proj_matrix,
#     472         reproj_error_threshold=reproj_error_threshold
#     473     )
#     474     if point3d is not None:
#     475         good_tracks.append(track)
#
# File c:\Users\kirill-korolev\ami\sfm\estimate_trajectory.py:445, in triangulate_track(track, frame_to_keypoints, intrinsics_mat, frame_to_extrinsic_mat, frame_to_proj_matrix, reproj_error_threshold)
#     442         res.append(error)
#     443     return np.array(res, dtype=np.float64).ravel()
# --> 445 ls_result = least_squares(res_fn, x0=point3d, method="lm")
#     446 point3d = ls_result.x
#     448 for i in range(len(track)):
#
# File c:\Users\kirill-korolev\ami\sfm\venv\lib\site-packages\scipy\optimize\_lsq\least_squares.py:924, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     921             tr_solver = 'lsmr'
#     923 if method == 'lm':
# --> 924     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     925                           max_nfev, x_scale, diff_step)
#     927 elif method == 'trf':
#     928     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     929                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     930                  tr_options.copy(), verbose)
#
# File c:\Users\kirill-korolev\ami\sfm\venv\lib\site-packages\scipy\optimize\_lsq\least_squares.py:62, in call_minpack(fun, x0, jac, ftol, xtol, gtol, max_nfev, x_scale, diff_step)
#      59     if max_nfev is None:
#      60         # n squared to account for Jacobian evaluations.
#      61         max_nfev = 100 * n * (n + 1)
# ---> 62     x, info, status = _minpack._lmdif(
#      63         fun, x0, (), full_output, ftol, xtol, gtol,
#      64         max_nfev, epsfcn, factor, diag)
#      65 else:
#      66     if max_nfev is None:
#
# File c:\Users\kirill-korolev\ami\sfm\venv\lib\site-packages\scipy\optimize\_lsq\least_squares.py:815, in least_squares.<locals>.fun_wrapped(x)
#     814 def fun_wrapped(x):
# --> 815     return np.atleast_1d(fun(x, *args, **kwargs))
#
# File c:\Users\kirill-korolev\ami\sfm\estimate_trajectory.py:441, in triangulate_track.<locals>.res_fn(x)
#     439     frame_id = track.get_frame(i)
#     440     point2d = frame_to_keypoints[frame_id].get_point2d(track[i])
# --> 441     error = reprojection_error(point2d, x, intrinsics_mat, frame_to_extrinsic_mat[frame_id])
#     442     res.append(error)
#     443 return np.array(res, dtype=np.float64).ravel()
#
# File c:\Users\kirill-korolev\ami\sfm\estimate_trajectory.py:373, in reprojection_error(point2d, point3d, intrinsics_mat, extrinsic_mat)
#     368 def reprojection_error(
#     369         point2d: np.array,
#     370         point3d: np.array,
#     371         intrinsics_mat: np.array,
#     372         extrinsic_mat: Dict[int, np.array]) -> float:
# --> 373     reproj_point = project_points3d(point3d.reshape(-1, 1), intrinsics_mat, extrinsic_mat).ravel()
#     374     return np.linalg.norm(reproj_point - point2d)
#
# File c:\Users\kirill-korolev\ami\sfm\estimate_trajectory.py:365, in project_points3d(points3d, intrinsics_mat, extrinsic_mat)
#     363 R = extrinsic_mat[:3,:3]
#     364 t = extrinsic_mat[:3,-1]
# --> 365 proj_points, _ = cv.projectPoints(points3d, R, t, intrinsics_mat, None)
#     366 return proj_points
#
# KeyboardInterrupt:

# %%
frame_id = 43
img = cv.imread(frame_to_image_path[frame_id])
kp = anchor_frame_to_keypoints[frame_id].kp
points3d = [tuple(point) for point in anchor_frame_to_keypoints[frame_id].points3d]
print(len(kp), len(set(kp)), len(set(points3d)))
plt.imshow(cv.drawKeypoints(img, kp, None, color=(0,255,0), flags=0))
# Out:
# 127 127 125
